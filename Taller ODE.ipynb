# %% [markdown]
# # Trabajo en clase ODE Metodo Euler
#
# Nombre: Jorge Yanez

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2
from src import ODE_euler
def f(t: float, y: float) -> float:
    return y - t**2 + 1  

a = 0.0
b = 2.0
y_t0 = 0.5
N = 10

y_values, t_values, h_value = ODE_euler(a = a, b= b, f= f, y_t0=y_t0, N=N)

# %% [markdown]
# ### Grafica Y real y aproximacion

# %%
import matplotlib.pyplot as plt
import numpy as np

def y_real(t):
    return (t+1)**2 -0.5*np.exp(t)

t_cont_real = np.linspace(a, b, 100)
y_cont_real = y_real(t_cont_real)


plt.plot(t_values, y_values, 'o-', label='Solucion Euler')
plt.plot(t_cont_real, y_cont_real, label='Solucion Real')
plt.xlabel('t')
plt.ylabel('y')
plt.title('Real vs Aproximado')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Graficos con N5, N20

# %%
a = 0.0
b = 2.0
y_t0 = 0.5
N = 5

y_values5, t_values5, h_value5 = ODE_euler(a = a, b= b, f= f, y_t0=y_t0, N=N)

plt.plot(t_values5, y_values5, 'o-', label='Solucion Euler N = 5')
plt.plot(t_cont_real, y_cont_real, label='Solucion Real')
plt.xlabel('t')
plt.ylabel('y')
plt.title('Real vs Aproximado')
plt.legend()
plt.grid(True)
plt.show()

# %%
a = 0.0
b = 2.0
y_t0 = 0.5
N = 20

y_values20, t_values20, h_value20 = ODE_euler(a = a, b= b, f= f, y_t0=y_t0, N=N)

plt.plot(t_values20, y_values20, 'o-', label='Solucion Euler N = 20')
plt.plot(t_cont_real, y_cont_real, label='Solucion Real')
plt.xlabel('t')
plt.ylabel('y')
plt.title('Real vs Aproximado')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### Graficas juntas

# %%
plt.plot(t_values5, y_values5, 'o-', label='Solucion Euler N = 5')
plt.plot(t_values, y_values, 'o-', label='Solucion Euler N = 10')
plt.plot(t_values20, y_values20, 'o-', label='Solucion Euler N = 20')
plt.plot(t_cont_real, y_cont_real, label='Solucion Real')
plt.xlabel('t')
plt.ylabel('y')
plt.title('Real vs Aproximado')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Ejercico 3

# %%
def f(t: float, y: float) -> float:
    return y/t - (y/t)**2 

a = 1.0
b = 2.0
y_t0 = 1.0
N = 10

y_values_ej3, t_values_ej3, h_value_ej3 = ODE_euler(a = a, b= b, f= f, y_t0=y_t0, N=N)

# %%
def y_real_ej3(t):
    return t/(1+np.log(t))

t_cont_real_ej3 = np.linspace(a, b, 100)
y_cont_real_ej3 = y_real_ej3(t_cont_real_ej3)


plt.plot(t_values_ej3, y_values_ej3, 'o-', label='Solucion Euler')
plt.plot(t_cont_real_ej3, y_cont_real_ej3, label='Solucion Real')
plt.xlabel('t')
plt.ylabel('y')
plt.title('Real vs Aproximado ejercicio 3')
plt.legend()
plt.grid(True)
plt.show()
